# %% [markdown]
# # Clustering and Visualization

# %%
import pandas as pd 
import numpy as np
import math
from datetime import datetime
import joblib
import sklearn
from sklearn.cluster import KMeans 
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D

# %%
start_time = datetime.now()
sender = joblib.load('sender_data')
duration = datetime.now() - start_time
print("Loaded dataset in: ", duration)
# Out:
# Loaded dataset in:  0:06:57.303091

# %%
start_time = datetime.now()
receiver = joblib.load('receiver_data')
duration = datetime.now() - start_time
print("Loaded dataset in: ", duration)
# Out:
# Loaded dataset in:  0:10:28.731772

# %%
sender.head(15)
# Out:
#                         044f9d391a27b59859fb3b274237671ff246bb9b69ae7d66db3a7a3875b9520d  \
# amounts                  [500.0, 250.0, 2000.0, 1500.0, 100.0, 50.0, 90...
# locations                [(44.53, -78.75), (43.58, -79.63), (32.84, -80...
# receivers                {'2fe5ce59f8fbac0fccaca974b9bb08ab4b2afe3d5703...
# senderISP                      [Cable Cable, Virgin Mobile, AT&T Services]
# time_stamps              [2018-06-01 19:02:54.026-0400, 2018-02-28 23:0...
# transactions                                                            13
# mean_transaction_amount                                            584.615
# transacton_std_dev                                                 159.732
# total_ISPs                                                               3
# mean_trans_times                                                   24.7563
# trans_times_std                                                    20.1415
# transaction_frequency                                            0.0403937
# distance_from_border                                                1.1875
# unique_receivers                                                         3
# night_time                                                               1
#
#                         3ec92838d15518ea50355e7adfa01d470a7e49479c426db3ffc65befe6a2e622  \
# amounts                  [2571.0, 90.0, 2571.0, 2571.0, 2571.0, 150.0, ...
# locations                [(43.89, -78.88), (43.74, -79.59), (43.51, -79...
# receivers                {'480e4ce89838a108880a7ba13475d9aa92e995476a86...
# senderISP                [Primus Telecommunications Canada, Bell Canada...
# time_stamps              [2018-06-01 05:37:11.480-0400, 2018-03-01 09:4...
# transactions                                                            16
# mean_transaction_amount                                            1291.38
# transacton_std_dev                                                  287.12
# total_ISPs                                                               3
# mean_trans_times                                                   16.9869
# trans_times_std                                                    15.5028
# transaction_frequency                                            0.0588691
# distance_from_border                                               0.59976
# unique_receivers                                                         8
# night_time                                                               1
#
#                         0f772a1e33aec1998c7a917e5cf67f30eeb485db693c57da470cf67d340c2453  \
# amounts                  [1025.0, 1025.0, 1025.0, 1025.0, 1025.0, 500.0...
# locations                [(45.73, -73.71), (44.31, -78.36), (43.66, -79...
# receivers                {'02fc4c55153e0f1645e8c3b24a0d225aa09a3e6806a6...
# senderISP                [Bell Canada, Cogeco Cable, GONET, Bell Mobility]
# time_stamps              [2018-06-01 00:44:01.691-0400, 2018-04-30 10:5...
# transactions                                                            14
# mean_transaction_amount                                            675.214
# transacton_std_dev                                                 114.422
# total_ISPs                                                               4
# mean_trans_times                                                   19.6256
# trans_times_std                                                    10.2791
# transaction_frequency                                            0.0509539
# distance_from_border                                               0.36142
# unique_receivers                                                         4
# night_time                                                               1
#
#                         30e1bb678ca1426e122bdb953a2320abbacd14a1dd093b77a4b2f33d84fc937e  \
# amounts                                      [1510.0, 800.0, 40.0, 1510.0]
# locations                               [(43.65, -79.42), (43.71, -79.39)]
# receivers                {'7e28bb7504342ed3806218195ab31d7dcab330cc7511...
# senderISP                                       [Amanah Tech, Bell Canada]
# time_stamps              [2018-06-01 00:33:22.304-0400, 2018-06-01 00:3...
# transactions                                                             4
# mean_transaction_amount                                                965
# transacton_std_dev                                                 303.819
# total_ISPs                                                               2
# mean_trans_times                                                   23.2123
# trans_times_std                                                    31.3969
# transaction_frequency                                            0.0430806
# distance_from_border                                               0.57684
# unique_receivers                                                         2
# night_time                                                               3
#
#                         5f1331872f036401287146d98e5b7f9d23a24a789b4d72c3731dcabfc67bbc48  \
# amounts                  [69.0, 469.0, 69.0, 69.0, 473.0, 69.0, 69.0, 5...
# locations                [(45.55, -73.58), (45.38, -71.93), (45.64, -73...
# receivers                {'42ad4701060ceaebd11b09360ca9a24d75d217f90921...
# senderISP                        [Distributel Communications, Bell Canada]
# time_stamps              [2018-06-01 19:27:57.245-0400, 2017-12-01 06:1...
# transactions                                                            13
# mean_transaction_amount                                            160.769
# transacton_std_dev                                                 52.6085
# total_ISPs                                                               2
# mean_trans_times                                                   19.9563
# trans_times_std                                                    12.2087
# transaction_frequency                                            0.0501095
# distance_from_border                                               0.12916
# unique_receivers                                                         5
# night_time                                                               4
#
#                         a844f08602b27f68ecbe4685991c427948dc3ade39775ea3d29e99bc1c789c1d  \
# amounts                  [820.0, 820.0, 820.0, 820.0, 820.0, 820.0, 820...
# locations                                               [(50.05, -119.29)]
# receivers                {'a81fd73419341dda2674163e8c5916943968d2857aa8...
# senderISP                                            [Shaw Communications]
# time_stamps              [2018-06-01 00:12:43.788-0400, 2017-12-01 19:5...
# transactions                                                            16
# mean_transaction_amount                                             513.86
# transacton_std_dev                                                 88.2987
# total_ISPs                                                               1
# mean_trans_times                                                   20.1538
# trans_times_std                                                    13.9252
# transaction_frequency                                            0.0496183
# distance_from_border                                                  1.05
# unique_receivers                                                         4
# night_time                                                               4
#
#                         800012ea1c431863b68eff6dbf714090466718395a6158b76e62b9e16b63d6f8  \
# amounts                  [666.66, 725.0, 330.0, 615.73, 250.0, 300.0, 4...
# locations                [(48.48, -123.37), (48.44, -123.36), (50.85, -...
# receivers                {'922efec678a4b9ef3feb83cfa94c2cb3328864a3ea4c...
# senderISP                                            [Shaw Communications]
# time_stamps              [2018-06-01 11:05:43.082-0400, 2017-12-01 15:3...
# transactions                                                             7
# mean_transaction_amount                                            469.627
# transacton_std_dev                                                 68.0241
# total_ISPs                                                               1
# mean_trans_times                                                   33.9927
# trans_times_std                                                    32.8779
# transaction_frequency                                            0.0294181
# distance_from_border                                                  0.52
# unique_receivers                                                         3
# night_time                                                               0
#
#                         01fad62c3e5b6cbf95a26d59abd3249796e56a1caa027b013b470e06ffc4afba  \
# amounts                  [350.0, 350.0, 350.0, 680.0, 350.0, 350.0, 350...
# locations                [(45.33, -75.67), (45.42, -75.7), (45.33, -75....
# receivers                {'bf6f30e2e6e31010cfcd15eb765b7a4cfc21ff33fe29...
# senderISP                            [Shared Services Canada, Bell Canada]
# time_stamps              [2018-06-01 14:00:51.380-0400, 2018-06-15 15:4...
# transactions                                                            10
# mean_transaction_amount                                                383
# transacton_std_dev                                                 31.3065
# total_ISPs                                                               2
# mean_trans_times                                                   14.7739
# trans_times_std                                                    9.31642
# transaction_frequency                                            0.0676871
# distance_from_border                                               0.74934
# unique_receivers                                                         1
# night_time                                                               0
#
#                         8b11e3e97273699aeca08dbb84f884921c53f7af83144143166db368cb1b7df7  \
# amounts                  [2776.57, 2742.65, 30.0, 776.57, 776.57, 600.0...
# locations                             [(49.28, -123.11), (49.26, -123.16)]
# receivers                {'99802f30b2029bcc495725c61b51464a4bd5a85ccbf3...
# senderISP                              [Bell Canada, Telus Communications]
# time_stamps              [2018-06-01 15:52:35.582-0400, 2018-05-01 13:4...
# transactions                                                            38
# mean_transaction_amount                                            746.537
# transacton_std_dev                                                 119.006
# total_ISPs                                                               2
# mean_trans_times                                                   7.75278
# trans_times_std                                                    6.46932
# transaction_frequency                                             0.128986
# distance_from_border                                                  0.28
# unique_receivers                                                        10
# night_time                                                               3
#
#                         831b7e058c9542cea19d2fecbebf0e838ee5a0ccaabe06e9b13eab2940cd9c0f  \
# amounts                    [200.0, 100.0, 150.0, 180.0, 60.0, 240.0, 40.0]
# locations                                                [(49.92, -96.96)]
# receivers                {'f2717c125ac73191416ed910bee13fbaaeb1c90d8a7b...
# senderISP                                            [Shaw Communications]
# time_stamps              [2018-06-01 08:22:02.319-0400, 2018-06-01 15:1...
# transactions                                                             7
# mean_transaction_amount                                            138.571
# transacton_std_dev                                                 26.0634
# total_ISPs                                                               1
# mean_trans_times                                                   25.1082
# trans_times_std                                                    20.7802
# transaction_frequency                                            0.0398276
# distance_from_border                                                  0.92
# unique_receivers                                                         3
# night_time                                                               1
#
#                          ...  \
# amounts                  ...
# locations                ...
# receivers                ...
# senderISP                ...
# time_stamps              ...
# transactions             ...
# mean_transaction_amount  ...
# transacton_std_dev       ...
# total_ISPs               ...
# mean_trans_times         ...
# trans_times_std          ...
# transaction_frequency    ...
# distance_from_border     ...
# unique_receivers         ...
# night_time               ...
#
#                         1353274bc61ab4fec631779f9ea5c0f9a312527034b859df6a7b97504560810c  \
# amounts                                                             [50.0]
# locations                                               [(49.23, -123.09)]
# receivers                {'eccb1f777dc4f296fd2608c4cb7f5506fc043cf5a3ca...
# senderISP                                           [Telus Communications]
# time_stamps                                 [2017-08-31 23:59:20.877-0400]
# transactions                                                             1
# mean_transaction_amount                                                 50
# transacton_std_dev                                                       0
# total_ISPs                                                               1
# mean_trans_times                                                         0
# trans_times_std                                                          0
# transaction_frequency                                                    0
# distance_from_border                                                  0.23
# unique_receivers                                                         1
# night_time                                                               1
#
#                         d8f6868e404062650b1fc105865c32741804224de10db31f90151d25da7bbf3f  \
# amounts                                                             [40.0]
# locations                                                 [(45.4, -75.73)]
# receivers                {'b4859deb2e5a15e33b480b321bba00f713d44fe160dd...
# senderISP                                                   [Rogers Cable]
# time_stamps                                 [2017-08-31 23:55:26.990-0400]
# transactions                                                             1
# mean_transaction_amount                                                 40
# transacton_std_dev                                                       0
# total_ISPs                                                               1
# mean_trans_times                                                         0
# trans_times_std                                                          0
# transaction_frequency                                                    0
# distance_from_border                                               0.84346
# unique_receivers                                                         1
# night_time                                                               1
#
#                         05bc9b38338301d280a26c5841d9fcd4f90aa89601116412ff455e8ab4477062  \
# amounts                                                            [200.0]
# locations                                                [(42.98, -79.25)]
# receivers                {'fa52e4777438010e3f0dcb10618f047e28f33845865b...
# senderISP                                                   [Cogeco Cable]
# time_stamps                                 [2017-08-31 23:57:03.494-0400]
# transactions                                                             1
# mean_transaction_amount                                                200
# transacton_std_dev                                                       0
# total_ISPs                                                               1
# mean_trans_times                                                         0
# trans_times_std                                                          0
# transaction_frequency                                                    0
# distance_from_border                                                0.1615
# unique_receivers                                                         1
# night_time                                                               1
#
#                         783da53293ca7d1246763514b4c559af348ad7dfb94b959b0a704c46f5f52c34  \
# amounts                                                            [800.0]
# locations                                                [(43.69, -79.76)]
# receivers                {'0a6b2cc63aa34eaabc0acfd054918c6973bd113582e5...
# senderISP                                                   [Rogers Cable]
# time_stamps                                 [2017-08-31 23:04:40.558-0400]
# transactions                                                             1
# mean_transaction_amount                                                800
# transacton_std_dev                                                       0
# total_ISPs                                                               1
# mean_trans_times                                                         0
# trans_times_std                                                          0
# transaction_frequency                                                    0
# distance_from_border                                               0.75352
# unique_receivers                                                         1
# night_time                                                               1
#
#                         c33f4c9784670bbb33b7a1eb621ce317cc79febdae0bc25c4112d332c3c5b732  \
# amounts                                                            [100.0]
# locations                                                 [(43.64, -79.4)]
# receivers                {'7a55e552f338e4532f3609ce5dbbf4fd9891f5c8c319...
# senderISP                                                    [Bell Canada]
# time_stamps                                 [2017-08-31 23:26:07.982-0400]
# transactions                                                             1
# mean_transaction_amount                                                100
# transacton_std_dev                                                       0
# total_ISPs                                                               1
# mean_trans_times                                                         0
# trans_times_std                                                          0
# transaction_frequency                                                    0
# distance_from_border                                                0.5588
# unique_receivers                                                         1
# night_time                                                               1
#
#                         4a0b27c8d31bb704126488a37bbd586eeebe38247bed9d43b79fbdd362d04ffb  \
# amounts                                                           [1000.0]
# locations                                               [(49.12, -123.12)]
# receivers                {'30d4adfb33cb3c4564fdcee6608559e36df85b6927f3...
# senderISP                                            [Shaw Communications]
# time_stamps                                 [2017-08-31 23:57:10.302-0400]
# transactions                                                             1
# mean_transaction_amount                                               1000
# transacton_std_dev                                                       0
# total_ISPs                                                               1
# mean_trans_times                                                         0
# trans_times_std                                                          0
# transaction_frequency                                                    0
# distance_from_border                                                  0.12
# unique_receivers                                                         1
# night_time                                                               1
#
#                         c6495247effccf9064872c4846785e3972a7ba70631f41e6b4187b43c9e9d132  \
# amounts                                                            [440.0]
# locations                                               [(50.02, -119.41)]
# receivers                {'b06a1b5f7824a09ef9a5b482bf459043e374e80f48ce...
# senderISP                                            [Shaw Communications]
# time_stamps                                 [2017-08-31 23:50:26.566-0400]
# transactions                                                             1
# mean_transaction_amount                                                440
# transacton_std_dev                                                       0
# total_ISPs                                                               1
# mean_trans_times                                                         0
# trans_times_std                                                          0
# transaction_frequency                                                    0
# distance_from_border                                                  1.02
# unique_receivers                                                         1
# night_time                                                               1
#
#                         43909c74bc561391b41c955ebcf9e091ce64ba2b2473ee03c3ed30803859f298  \
# amounts                                                            [700.0]
# locations                                               [(49.32, -124.32)]
# receivers                {'858a04e39f9bd4d4e908d87758a86fd850908c07a10f...
# senderISP                                            [Shaw Communications]
# time_stamps                                 [2017-08-31 22:59:58.156-0400]
# transactions                                                             1
# mean_transaction_amount                                                700
# transacton_std_dev                                                       0
# total_ISPs                                                               1
# mean_trans_times                                                         0
# trans_times_std                                                          0
# transaction_frequency                                                    0
# distance_from_border                                                  0.32
# unique_receivers                                                         1
# night_time                                                               0
#
#                         dc3dfde35fabbb4cae101eb8e6289e058dec34006e336832bbb172bea12fef11  \
# amounts                                                            [480.0]
# locations                                                 [(45.5, -73.59)]
# receivers                {'cfa22cf3d791365d43e754bd4fa79dfdc11cf3c04872...
# senderISP                                                    [Bell Canada]
# time_stamps                                 [2017-08-31 23:03:41.750-0400]
# transactions                                                             1
# mean_transaction_amount                                                480
# transacton_std_dev                                                       0
# total_ISPs                                                               1
# mean_trans_times                                                         0
# trans_times_std                                                          0
# transaction_frequency                                                    0
# distance_from_border                                               0.08318
# unique_receivers                                                         1
# night_time                                                               1
#
#                         02e5ce0630bf03b7a491c7cde335e08dd14358a72da6736b91cec0ca03f939b7
# amounts                                                            [500.0]
# locations                                               [(52.16, -106.69)]
# receivers                {'d5978bf81a7e999dc4ec2acf5eae095c03bf0ef1390f...
# senderISP                                            [Shaw Communications]
# time_stamps                                 [2017-08-31 23:04:53.080-0400]
# transactions                                                             1
# mean_transaction_amount                                                500
# transacton_std_dev                                                       0
# total_ISPs                                                               1
# mean_trans_times                                                         0
# trans_times_std                                                          0
# transaction_frequency                                                    0
# distance_from_border                                                  3.16
# unique_receivers                                                         1
# night_time                                                               1
#
# [15 rows x 1173094 columns]

# %%
receiver.head(15)
# Out:
#                         2fe5ce59f8fbac0fccaca974b9bb08ab4b2afe3d5703d110a400db4053f82f74  \
# amounts                                                            [500.0]
# senders                  {'044f9d391a27b59859fb3b274237671ff246bb9b69ae...
# time_stamps                                 [2018-06-01 19:02:54.026-0400]
# transactions                                                             1
# mean_transaction_amount                                                500
# transacton_std_dev                                                       0
# transaction_frequency                                                    0
# unique_senders                                                           1
# night_time                                                               0
# mean_trans_times                                                         0
# trans_times_std                                                          0
#
#                         480e4ce89838a108880a7ba13475d9aa92e995476a86ea093ec85ba9561bff19  \
# amounts                  [2571.0, 2571.0, 2571.0, 2571.0, 2571.0, 2571....
# senders                  {'3ec92838d15518ea50355e7adfa01d470a7e49479c42...
# time_stamps              [2018-06-01 05:37:11.480-0400, 2018-03-01 09:4...
# transactions                                                             7
# mean_transaction_amount                                               2571
# transacton_std_dev                                                       0
# transaction_frequency                                            0.0403514
# unique_senders                                                           1
# night_time                                                               1
# mean_trans_times                                                   24.7823
# trans_times_std                                                     10.061
#
#                         02fc4c55153e0f1645e8c3b24a0d225aa09a3e6806a6523e023b951f8ccd424f  \
# amounts                  [1025.0, 1025.0, 1025.0, 1025.0, 1025.0, 500.0...
# senders                  {'0f772a1e33aec1998c7a917e5cf67f30eeb485db693c...
# time_stamps              [2018-06-01 00:44:01.691-0400, 2018-04-30 10:5...
# transactions                                                            10
# mean_transaction_amount                                              922.5
# transacton_std_dev                                                 64.8508
# transaction_frequency                                            0.0373665
# unique_senders                                                           1
# night_time                                                               1
# mean_trans_times                                                   26.7619
# trans_times_std                                                    9.50867
#
#                         7e28bb7504342ed3806218195ab31d7dcab330cc7511ad7e99470d35faf27097  \
# amounts                                                   [1510.0, 1510.0]
# senders                  {'30e1bb678ca1426e122bdb953a2320abbacd14a1dd09...
# time_stamps              [2018-06-01 00:33:22.304-0400, 2018-03-23 09:1...
# transactions                                                             2
# mean_transaction_amount                                               1510
# transacton_std_dev                                                       0
# transaction_frequency                                            0.0143604
# unique_senders                                                           1
# night_time                                                               1
# mean_trans_times                                                   69.6358
# trans_times_std                                                          0
#
#                         42ad4701060ceaebd11b09360ca9a24d75d217f90921deecae5fe2238750f76c  \
# amounts                  [69.0, 469.0, 69.0, 69.0, 473.0, 69.0, 69.0, 6...
# senders                  {'5f1331872f036401287146d98e5b7f9d23a24a789b4d...
# time_stamps              [2018-06-01 19:27:57.245-0400, 2017-12-01 06:1...
# transactions                                                             9
# mean_transaction_amount                                            213.889
# transacton_std_dev                                                 68.8782
# transaction_frequency                                            0.0334063
# unique_senders                                                           1
# night_time                                                               4
# mean_trans_times                                                   29.9345
# trans_times_std                                                     2.3085
#
#                         a81fd73419341dda2674163e8c5916943968d2857aa829450c1177858ebcec6c  \
# amounts                  [820.0, 820.0, 820.0, 820.0, 820.0, 500.0, 820...
# senders                  {'a844f08602b27f68ecbe4685991c427948dc3ade3977...
# time_stamps              [2018-06-01 00:12:43.788-0400, 2017-12-01 19:5...
# transactions                                                            11
# mean_transaction_amount                                            743.636
# transacton_std_dev                                                 50.5061
# transaction_frequency                                            0.0330789
# unique_senders                                                           2
# night_time                                                               5
# mean_trans_times                                                   30.2308
# trans_times_std                                                    22.2541
#
#                         922efec678a4b9ef3feb83cfa94c2cb3328864a3ea4c6fb4e2b252340eb8949d  \
# amounts                                     [666.66, 330.0, 615.73, 250.0]
# senders                  {'800012ea1c431863b68eff6dbf714090466718395a61...
# time_stamps              [2018-06-01 11:05:43.082-0400, 2018-04-30 22:2...
# transactions                                                             4
# mean_transaction_amount                                            465.597
# transacton_std_dev                                                  89.385
# transaction_frequency                                            0.0197931
# unique_senders                                                           1
# night_time                                                               0
# mean_trans_times                                                   50.5226
# trans_times_std                                                    49.2358
#
#                         bf6f30e2e6e31010cfcd15eb765b7a4cfc21ff33fe295b2629a1f7aa7560a348  \
# amounts                  [350.0, 350.0, 315.0, 350.0, 680.0, 350.0, 350...
# senders                  {'01fad62c3e5b6cbf95a26d59abd3249796e56a1caa02...
# time_stamps              [2018-06-01 14:00:51.380-0400, 2018-06-15 15:4...
# transactions                                                            12
# mean_transaction_amount                                            357.083
# transacton_std_dev                                                 32.6623
# transaction_frequency                                            0.0827287
# unique_senders                                                           2
# night_time                                                               0
# mean_trans_times                                                   12.0877
# trans_times_std                                                    9.95663
#
#                         99802f30b2029bcc495725c61b51464a4bd5a85ccbf3080468d4684f69b99ded  \
# amounts                  [2776.57, 2742.65, 30.0, 776.57, 776.57, 2000....
# senders                  {'8b11e3e97273699aeca08dbb84f884921c53f7af8314...
# time_stamps              [2018-06-01 15:52:35.582-0400, 2018-05-01 13:4...
# transactions                                                            26
# mean_transaction_amount                                            939.639
# transacton_std_dev                                                 153.995
# transaction_frequency                                            0.0886622
# unique_senders                                                           1
# night_time                                                               2
# mean_trans_times                                                   11.2788
# trans_times_std                                                    6.06524
#
#                         f2717c125ac73191416ed910bee13fbaaeb1c90d8a7b2d789aeeafc854fddb67  \
# amounts                                                            [200.0]
# senders                  {'831b7e058c9542cea19d2fecbebf0e838ee5a0ccaabe...
# time_stamps                                 [2018-06-01 08:22:02.319-0400]
# transactions                                                             1
# mean_transaction_amount                                                200
# transacton_std_dev                                                       0
# transaction_frequency                                                    0
# unique_senders                                                           1
# night_time                                                               0
# mean_trans_times                                                         0
# trans_times_std                                                          0
#
#                          ...  \
# amounts                  ...
# senders                  ...
# time_stamps              ...
# transactions             ...
# mean_transaction_amount  ...
# transacton_std_dev       ...
# transaction_frequency    ...
# unique_senders           ...
# night_time               ...
# mean_trans_times         ...
# trans_times_std          ...
#
#                         0d8ee3425fd2ad48cc8fd22e236052d22150db2ae953b1f7992a55aeeb2e279e  \
# amounts                                                            [100.0]
# senders                  {'a1a6506a2ec1d7a42117fdbf34ad521f4191a7094ea3...
# time_stamps                                 [2017-08-31 23:53:10.725-0400]
# transactions                                                             1
# mean_transaction_amount                                                100
# transacton_std_dev                                                       0
# transaction_frequency                                                    0
# unique_senders                                                           1
# night_time                                                               1
# mean_trans_times                                                         0
# trans_times_std                                                          0
#
#                         6bcfd30e37b050170b19a0acd4b91f8bb8a05affea8cdc6bb92b524da4dc19c7  \
# amounts                                                             [20.0]
# senders                  {'71e34674800c09cf437327f2fe5678da07d6015a4b41...
# time_stamps                                 [2017-08-31 23:56:52.859-0400]
# transactions                                                             1
# mean_transaction_amount                                                 20
# transacton_std_dev                                                       0
# transaction_frequency                                                    0
# unique_senders                                                           1
# night_time                                                               1
# mean_trans_times                                                         0
# trans_times_std                                                          0
#
#                         87283b531005bb16d1bff927648d38d143cf21d2a09aa4a9cefdb47d1e7d4d1e  \
# amounts                                                            [100.0]
# senders                  {'810be5f0a72a2e79127ef47d0ba7e48731a29d6dc760...
# time_stamps                                 [2017-08-31 23:59:49.201-0400]
# transactions                                                             1
# mean_transaction_amount                                                100
# transacton_std_dev                                                       0
# transaction_frequency                                                    0
# unique_senders                                                           1
# night_time                                                               1
# mean_trans_times                                                         0
# trans_times_std                                                          0
#
#                         606b5bf23b9b8001fc9717c97224b06cbb01a2108cccd30087da230460f9b9a6  \
# amounts                                                           [224.87]
# senders                  {'81d730e1c5fa7033fec80349c8f7dbb6d72966fa60cd...
# time_stamps                                 [2017-08-31 23:35:36.215-0400]
# transactions                                                             1
# mean_transaction_amount                                             224.87
# transacton_std_dev                                                       0
# transaction_frequency                                                    0
# unique_senders                                                           1
# night_time                                                               1
# mean_trans_times                                                         0
# trans_times_std                                                          0
#
#                         18e7f1f03c26fa1f6b821a43928042b4caf81342fde77526b02a959f17c523b1  \
# amounts                                                           [1000.0]
# senders                  {'d9291eb7de5f0d089c48ccac57cc3fe66493cdbbb6e2...
# time_stamps                                 [2017-08-31 23:54:33.430-0400]
# transactions                                                             1
# mean_transaction_amount                                               1000
# transacton_std_dev                                                       0
# transaction_frequency                                                    0
# unique_senders                                                           1
# night_time                                                               1
# mean_trans_times                                                         0
# trans_times_std                                                          0
#
#                         b7f82d880e7469add556fa93d50810474e688f0dcf0e7bb9770cef27ea5299d4  \
# amounts                                                            [200.0]
# senders                  {'fb125d26fff3a473da9430ea0a77555d2977f6c3786e...
# time_stamps                                 [2017-08-31 23:54:47.951-0400]
# transactions                                                             1
# mean_transaction_amount                                                200
# transacton_std_dev                                                       0
# transaction_frequency                                                    0
# unique_senders                                                           1
# night_time                                                               1
# mean_trans_times                                                         0
# trans_times_std                                                          0
#
#                         a43632656882d7515f7a5445c982d5077f2a007502133744eea1869e8c806740  \
# amounts                                                            [500.0]
# senders                  {'aa07cf0e58f300caf64ec51c96ca0732a49cd2050ddd...
# time_stamps                                 [2017-08-31 23:37:28.421-0400]
# transactions                                                             1
# mean_transaction_amount                                                500
# transacton_std_dev                                                       0
# transaction_frequency                                                    0
# unique_senders                                                           1
# night_time                                                               1
# mean_trans_times                                                         0
# trans_times_std                                                          0
#
#                         25bffa2f0bc780e3ee52534a1b1b51b7c100d88e10132ca04ef4e7489f23bfa2  \
# amounts                                                            [900.0]
# senders                  {'1642b76e70a38bed51b72ba26102fdec6f42dee22e0b...
# time_stamps                                 [2017-08-31 23:18:16.956-0400]
# transactions                                                             1
# mean_transaction_amount                                                900
# transacton_std_dev                                                       0
# transaction_frequency                                                    0
# unique_senders                                                           1
# night_time                                                               1
# mean_trans_times                                                         0
# trans_times_std                                                          0
#
#                         d5978bf81a7e999dc4ec2acf5eae095c03bf0ef1390fbfa0ea0d80ccdb001e14  \
# amounts                                                            [500.0]
# senders                  {'02e5ce0630bf03b7a491c7cde335e08dd14358a72da6...
# time_stamps                                 [2017-08-31 23:04:53.080-0400]
# transactions                                                             1
# mean_transaction_amount                                                500
# transacton_std_dev                                                       0
# transaction_frequency                                                    0
# unique_senders                                                           1
# night_time                                                               1
# mean_trans_times                                                         0
# trans_times_std                                                          0
#
#                         eab2cd9a6a6bd5c18862b911dd7cef59bd4a801c785fefa1e235a020aee7a310
# amounts                                                             [20.0]
# senders                  {'1b92b012dc62df94bc58ce2d403a5fbb687fcae1589b...
# time_stamps                                 [2017-08-31 23:29:11.151-0400]
# transactions                                                             1
# mean_transaction_amount                                                 20
# transacton_std_dev                                                       0
# transaction_frequency                                                    0
# unique_senders                                                           1
# night_time                                                               1
# mean_trans_times                                                         0
# trans_times_std                                                          0
#
# [11 rows x 2727049 columns]

# %% [markdown]
# # Exploring Data - Visualization

# %%
cluster_amount = 5

# %%
mstd = [] 
m_total_transactions = [] 
mtransf = [] 
mean_ISP = [] 
mean_border = [] 

transf_std = [] 
transf_total_transactions = [] 
transf_ISP = [] 
transf_border = [] 

ISP_std = [] 
ISP_total_transactions = [] 
ISP_border = [] 

total_transactions_std = [] 
total_transactions_border = [] 

border_std = [] 

for name in sender.iteritems(): 
    account_num = name[0]
    value = name[1]
    
    total_transaction = value['transactions']
    mean_trans = value['mean_transaction_amount']
    std_trans = value['transacton_std_dev']
    trans_frequency = value['transaction_frequency']
    senderISP = value['total_ISPs']
    distance_us = value['distance_from_border']
    
    mstd.append([mean_trans,std_trans])
    m_total_transactions.append([mean_trans,total_transaction])
    mtransf.append([trans_frequency,mean_trans])
    mean_ISP.append([senderISP,mean_trans])
    mean_border.append([distance_us,mean_trans])
    
    transf_std.append([trans_frequency,std_trans])
    transf_total_transactions.append([trans_frequency,total_transaction])
    transf_ISP.append([senderISP,trans_frequency])
    transf_border.append([distance_us,trans_frequency])
    
    ISP_total_transactions.append([senderISP,total_transaction])
    ISP_std.append([senderISP,std_trans])
    ISP_border.append([senderISP,distance_us])
    
    total_transactions_std.append([total_transaction,std_trans])
    total_transactions_border.append([total_transaction,distance_us]) 

    border_std.append([distance_us,std_trans])

    
all_features = [mstd, m_total_transactions, mtransf, mean_ISP, mean_border, transf_std, transf_total_transactions,
               transf_ISP, transf_border, ISP_std, ISP_total_transactions,ISP_border,total_transactions_std, 
               total_transactions_std, total_transactions_border, border_std] 

for i in range(len(all_features)): 
    all_features[i] = sklearn.preprocessing.scale(all_features[i])

# %%
#print(np.shape(cluster_data_mstd))
kmeans = KMeans(n_clusters=cluster_amount, random_state=0).fit(all_features[0])
centers = kmeans.cluster_centers_
labels = kmeans.labels_
np.shape(centers)

x = [] 
y = []

center_x = [] 
center_y = [] 

for point in all_features[0]: 
    x.append(point[0])
    y.append(point[1])
    
for point in centers: 
    center_x.append(point[0])
    center_y.append(point[1])
    
plt.scatter(x,y,c=labels.astype(float))
plt.scatter(center_x,center_y,marker="x",s=200)
plt.title('Mean Transaction Amount vs. Spontenaity in Transaction Amount')
plt.ylabel('Transaction Amount Standard Deviation')
plt.xlabel('Mean Transaction Amount')
plt.show()

# %%
#print(np.shape(cluster_data_mstd))
kmeans = KMeans(n_clusters=cluster_amount, random_state=0).fit(all_features[1])
centers = kmeans.cluster_centers_
labels = kmeans.labels_
np.shape(centers)

x = [] 
y = []

center_x = [] 
center_y = [] 

for point in all_features[1]: 
    x.append(point[0])
    y.append(point[1])
    
for point in centers: 
    center_x.append(point[0])
    center_y.append(point[1])
    
plt.scatter(x,y,c=labels.astype(float))
plt.scatter(center_x,center_y,marker="x",s=200)
plt.title('Mean Transaction Amount vs. Total Transactions')
plt.ylabel('Total Transactions')
plt.xlabel('Mean Transaction Amount')
plt.show()

# %%
#print(np.shape(cluster_data_mstd))
kmeans = KMeans(n_clusters=cluster_amount, random_state=0).fit(all_features[2])
centers = kmeans.cluster_centers_
labels = kmeans.labels_
np.shape(centers)

x = [] 
y = []

center_x = [] 
center_y = [] 

for point in all_features[2]: 
    x.append(point[0])
    y.append(point[1])
    
for point in centers: 
    center_x.append(point[0])
    center_y.append(point[1])
    
plt.scatter(x,y,c=labels.astype(float))
plt.scatter(center_x,center_y,marker="x",s=200)
plt.title('Average Transaction Period vs. Mean Transaction Amount')
plt.xlabel('Average Transaction Gap')
plt.ylabel('Mean Transaction Amount')
plt.show()

# %%
#print(np.shape(cluster_data_mstd))
kmeans = KMeans(n_clusters=cluster_amount, random_state=0).fit(all_features[3])
centers = kmeans.cluster_centers_
labels = kmeans.labels_
np.shape(centers)

x = [] 
y = []

center_x = [] 
center_y = [] 

for point in all_features[3]: 
    x.append(point[0])
    y.append(point[1])
    
for point in centers: 
    center_x.append(point[0])
    center_y.append(point[1])
    
plt.scatter(x,y,c=labels.astype(float))
plt.scatter(center_x,center_y,marker="x",s=200)
plt.title('Total Number of ISPs Used vs. Mean Transaction Amount')
plt.xlabel('Total Number of ISPs Used')
plt.ylabel('Mean Transaction Amount')
plt.show()

# %%
#print(np.shape(cluster_data_mstd))
kmeans = KMeans(n_clusters=cluster_amount, random_state=0).fit(all_features[5])
centers = kmeans.cluster_centers_
labels = kmeans.labels_
np.shape(centers)

x = [] 
y = []

center_x = [] 
center_y = [] 

for point in all_features[5]: 
    x.append(point[0])
    y.append(point[1])
    
for point in centers: 
    center_x.append(point[0])
    center_y.append(point[1])
    
plt.scatter(x,y,c=labels.astype(float))
plt.scatter(center_x,center_y,marker="x",s=200)
plt.title('Average Transaction Period vs. Transaction Amount Standard Deviation')
plt.ylabel('Transaction Amount Standard Deviation')
plt.xlabel('Average Transaction Period')
plt.show()

# %%
#print(np.shape(cluster_data_mstd))
kmeans = KMeans(n_clusters=cluster_amount, random_state=0).fit(all_features[6])
centers = kmeans.cluster_centers_
labels = kmeans.labels_
np.shape(centers)

x = [] 
y = []

center_x = [] 
center_y = [] 

for point in all_features[6]: 
    x.append(point[0])
    y.append(point[1])
    
for point in centers: 
    center_x.append(point[0])
    center_y.append(point[1])
    
plt.scatter(x,y,c=labels.astype(float))
plt.scatter(center_x,center_y,marker="x",s=200)
plt.title('Average Transaction Period vs. Total Number of Transactions')
plt.ylabel('Total Number of Transactions')
plt.xlabel('Average Transaction Period')
plt.show()

# %%
#print(np.shape(cluster_data_mstd))
kmeans = KMeans(n_clusters=cluster_amount, random_state=0).fit(all_features[7])
centers = kmeans.cluster_centers_
labels = kmeans.labels_
np.shape(centers)

x = [] 
y = []

center_x = [] 
center_y = [] 

for point in all_features[7]: 
    x.append(point[0])
    y.append(point[1])
    
for point in centers: 
    center_x.append(point[0])
    center_y.append(point[1])
    
plt.scatter(x,y,c=labels.astype(float))
plt.scatter(center_x,center_y,marker="x",s=200)
plt.title('Number of ISPs Used vs. Average Transaction Period')
plt.xlabel('Number of ISPs Used')
plt.ylabel('Average Transaction Period')
plt.show()

# %%
#print(np.shape(cluster_data_mstd))
kmeans = KMeans(n_clusters=cluster_amount, random_state=0).fit(all_features[9])
centers = kmeans.cluster_centers_
labels = kmeans.labels_
np.shape(centers)

x = [] 
y = []

center_x = [] 
center_y = [] 

for point in all_features[9]: 
    x.append(point[0])
    y.append(point[1])
    
for point in centers: 
    center_x.append(point[0])
    center_y.append(point[1])
    
plt.scatter(x,y,c=labels.astype(float))
plt.scatter(center_x,center_y,marker="x",s=200)
plt.title('Number of ISPs Used vs. Transaction Amount Standard Deviation')
plt.ylabel('Transaction Amount Standard Deviation')
plt.xlabel('Number of ISPs Used')
plt.show()

# %%
#print(np.shape(cluster_data_mstd))
kmeans = KMeans(n_clusters=cluster_amount, random_state=0).fit(all_features[10])
centers = kmeans.cluster_centers_
labels = kmeans.labels_
np.shape(centers)

x = [] 
y = []

center_x = [] 
center_y = [] 

for point in all_features[10]: 
    x.append(point[0])
    y.append(point[1])
    
for point in centers: 
    center_x.append(point[0])
    center_y.append(point[1])
    
plt.scatter(x,y,c=labels.astype(float))
plt.scatter(center_x,center_y,marker="x",s=200)
plt.title('Number of ISPs Used vs. Total Number of Transactons')
plt.ylabel('Total Number of Transactions')
plt.xlabel('Number of ISPs Used')
plt.show()

# %%
#print(np.shape(cluster_data_mstd))
kmeans = KMeans(n_clusters=cluster_amount, random_state=0).fit(all_features[12])
centers = kmeans.cluster_centers_
labels = kmeans.labels_
np.shape(centers)

x = [] 
y = []

center_x = [] 
center_y = [] 

for point in all_features[12]: 
    x.append(point[0])
    y.append(point[1])
    
for point in centers: 
    center_x.append(point[0])
    center_y.append(point[1])
    
plt.scatter(x,y,c=labels.astype(float))
plt.scatter(center_x,center_y,marker="x",s=200)
plt.title('Total Number of Transactions vs. Transaction Amount Standard Deviation')
plt.ylabel('Transaction Amount Standard Deviation')
plt.xlabel('Total Number of Transactions')
plt.show()

# %%
#print(np.shape(mean_border))
kmeans = KMeans(n_clusters=cluster_amount, random_state=0).fit(all_features[4])
centers = kmeans.cluster_centers_
labels = kmeans.labels_
np.shape(centers)

x = [] 
y = []

center_x = [] 
center_y = [] 

for point in all_features[4]: 
    x.append(point[0])
    y.append(point[1])
    
for point in centers: 
    center_x.append(point[0])
    center_y.append(point[1])
    
plt.scatter(x,y,c=labels.astype(float))
plt.scatter(center_x,center_y,marker="x",s=200)
plt.title('Distance from US border vs. Mean Transaction Amount')
plt.ylabel('Mean Transaction Amount')
plt.xlabel('Distance from US border')
plt.show()

# %%
#print(np.shape(mean_border))
kmeans = KMeans(n_clusters=cluster_amount, random_state=0).fit(all_features[8])
centers = kmeans.cluster_centers_
labels = kmeans.labels_
np.shape(centers)

x = [] 
y = []

center_x = [] 
center_y = [] 

for point in all_features[8]: 
    x.append(point[0])
    y.append(point[1])
    
for point in centers: 
    center_x.append(point[0])
    center_y.append(point[1])
    
plt.scatter(x,y,c=labels.astype(float))
plt.scatter(center_x,center_y,marker="x",s=200)
plt.title('Distance from US border vs. Transaction Frequency')
plt.ylabel('Transaction Frequency')
plt.xlabel('Distance from US border')
plt.show()

# %%
#print(np.shape(mean_border))
kmeans = KMeans(n_clusters=cluster_amount, random_state=0).fit(all_features[11])
centers = kmeans.cluster_centers_
labels = kmeans.labels_
np.shape(centers)

x = [] 
y = []

center_x = [] 
center_y = [] 

for point in all_features[11]: 
    x.append(point[0])
    y.append(point[1])
    
for point in centers: 
    center_x.append(point[0])
    center_y.append(point[1])
    
plt.scatter(x,y,c=labels.astype(float))
plt.scatter(center_x,center_y,marker="x",s=200)
plt.title('Total ISPs Used vs. Distance from US border')
plt.xlabel('Total ISPs Used')
plt.ylabel('Distance from US border')
plt.show()

# %%
#print(np.shape(mean_border))
kmeans = KMeans(n_clusters=cluster_amount, random_state=0).fit(all_features[14])
centers = kmeans.cluster_centers_
labels = kmeans.labels_
np.shape(centers)

x = [] 
y = []

center_x = [] 
center_y = [] 

for point in all_features[14]: 
    x.append(point[0])
    y.append(point[1])
    
for point in centers: 
    center_x.append(point[0])
    center_y.append(point[1])
    
plt.scatter(x,y,c=labels.astype(float))
plt.scatter(center_x,center_y,marker="x",s=200)
plt.title('Total Transactions vs. Distance from US border')
plt.xlabel('Total Transactions')
plt.ylabel('Distance from US border')
plt.show()

# %%
#print(np.shape(mean_border))
kmeans = KMeans(n_clusters=cluster_amount, random_state=0).fit(all_features[15])
centers = kmeans.cluster_centers_
labels = kmeans.labels_
np.shape(centers)

x = [] 
y = []

center_x = [] 
center_y = [] 

for point in all_features[15]: 
    x.append(point[0])
    y.append(point[1])
    
for point in centers: 
    center_x.append(point[0])
    center_y.append(point[1])
    
plt.scatter(x,y,c=labels.astype(float))
plt.scatter(center_x,center_y,marker="x",s=200)
plt.title('Distance from US border vs. Average Transaction Standard Deviation ')
plt.xlabel('Distance from US border')
plt.ylabel('Average Transaction Standard Deviation')
plt.show()

# %%
sender.head(17)
# Out:
#                         044f9d391a27b59859fb3b274237671ff246bb9b69ae7d66db3a7a3875b9520d  \
# amounts                  [500.0, 250.0, 2000.0, 1500.0, 100.0, 50.0, 90...
# locations                [(44.53, -78.75), (43.58, -79.63), (32.84, -80...
# receivers                {'2fe5ce59f8fbac0fccaca974b9bb08ab4b2afe3d5703...
# senderISP                      [Cable Cable, Virgin Mobile, AT&T Services]
# time_stamps              [2018-06-01 19:02:54.026-0400, 2018-02-28 23:0...
# transactions                                                            13
# mean_transaction_amount                                            584.615
# transacton_std_dev                                                 159.732
# total_ISPs                                                               3
# mean_trans_times                                                   24.7563
# trans_times_std                                                    20.1415
# transaction_frequency                                            0.0403937
# distance_from_border                                                1.1875
# unique_receivers                                                         3
# night_time                                                               1
# major_city                                                            0.11
#
#                         3ec92838d15518ea50355e7adfa01d470a7e49479c426db3ffc65befe6a2e622  \
# amounts                  [2571.0, 90.0, 2571.0, 2571.0, 2571.0, 150.0, ...
# locations                [(43.89, -78.88), (43.74, -79.59), (43.51, -79...
# receivers                {'480e4ce89838a108880a7ba13475d9aa92e995476a86...
# senderISP                [Primus Telecommunications Canada, Bell Canada...
# time_stamps              [2018-06-01 05:37:11.480-0400, 2018-03-01 09:4...
# transactions                                                            16
# mean_transaction_amount                                            1291.38
# transacton_std_dev                                                  287.12
# total_ISPs                                                               3
# mean_trans_times                                                   16.9869
# trans_times_std                                                    15.5028
# transaction_frequency                                            0.0588691
# distance_from_border                                               0.59976
# unique_receivers                                                         8
# night_time                                                               1
# major_city                                                            0.24
#
#                         0f772a1e33aec1998c7a917e5cf67f30eeb485db693c57da470cf67d340c2453  \
# amounts                  [1025.0, 1025.0, 1025.0, 1025.0, 1025.0, 500.0...
# locations                [(45.73, -73.71), (44.31, -78.36), (43.66, -79...
# receivers                {'02fc4c55153e0f1645e8c3b24a0d225aa09a3e6806a6...
# senderISP                [Bell Canada, Cogeco Cable, GONET, Bell Mobility]
# time_stamps              [2018-06-01 00:44:01.691-0400, 2018-04-30 10:5...
# transactions                                                            14
# mean_transaction_amount                                            675.214
# transacton_std_dev                                                 114.422
# total_ISPs                                                               4
# mean_trans_times                                                   19.6256
# trans_times_std                                                    10.2791
# transaction_frequency                                            0.0509539
# distance_from_border                                               0.36142
# unique_receivers                                                         4
# night_time                                                               1
# major_city                                                            0.23
#
#                         30e1bb678ca1426e122bdb953a2320abbacd14a1dd093b77a4b2f33d84fc937e  \
# amounts                                      [1510.0, 800.0, 40.0, 1510.0]
# locations                               [(43.65, -79.42), (43.71, -79.39)]
# receivers                {'7e28bb7504342ed3806218195ab31d7dcab330cc7511...
# senderISP                                       [Amanah Tech, Bell Canada]
# time_stamps              [2018-06-01 00:33:22.304-0400, 2018-06-01 00:3...
# transactions                                                             4
# mean_transaction_amount                                                965
# transacton_std_dev                                                 303.819
# total_ISPs                                                               2
# mean_trans_times                                                   23.2123
# trans_times_std                                                    31.3969
# transaction_frequency                                            0.0430806
# distance_from_border                                               0.57684
# unique_receivers                                                         2
# night_time                                                               3
# major_city                                                               0
#
#                         5f1331872f036401287146d98e5b7f9d23a24a789b4d72c3731dcabfc67bbc48  \
# amounts                  [69.0, 469.0, 69.0, 69.0, 473.0, 69.0, 69.0, 5...
# locations                [(45.55, -73.58), (45.38, -71.93), (45.64, -73...
# receivers                {'42ad4701060ceaebd11b09360ca9a24d75d217f90921...
# senderISP                        [Distributel Communications, Bell Canada]
# time_stamps              [2018-06-01 19:27:57.245-0400, 2017-12-01 06:1...
# transactions                                                            13
# mean_transaction_amount                                            160.769
# transacton_std_dev                                                 52.6085
# total_ISPs                                                               2
# mean_trans_times                                                   19.9563
# trans_times_std                                                    12.2087
# transaction_frequency                                            0.0501095
# distance_from_border                                               0.12916
# unique_receivers                                                         5
# night_time                                                               4
# major_city                                                            0.05
#
#                         a844f08602b27f68ecbe4685991c427948dc3ade39775ea3d29e99bc1c789c1d  \
# amounts                  [820.0, 820.0, 820.0, 820.0, 820.0, 820.0, 820...
# locations                                               [(50.05, -119.29)]
# receivers                {'a81fd73419341dda2674163e8c5916943968d2857aa8...
# senderISP                                            [Shaw Communications]
# time_stamps              [2018-06-01 00:12:43.788-0400, 2017-12-01 19:5...
# transactions                                                            16
# mean_transaction_amount                                             513.86
# transacton_std_dev                                                 88.2987
# total_ISPs                                                               1
# mean_trans_times                                                   20.1538
# trans_times_std                                                    13.9252
# transaction_frequency                                            0.0496183
# distance_from_border                                                  1.05
# unique_receivers                                                         4
# night_time                                                               4
# major_city                                                            0.16
#
#                         800012ea1c431863b68eff6dbf714090466718395a6158b76e62b9e16b63d6f8  \
# amounts                  [666.66, 725.0, 330.0, 615.73, 250.0, 300.0, 4...
# locations                [(48.48, -123.37), (48.44, -123.36), (50.85, -...
# receivers                {'922efec678a4b9ef3feb83cfa94c2cb3328864a3ea4c...
# senderISP                                            [Shaw Communications]
# time_stamps              [2018-06-01 11:05:43.082-0400, 2017-12-01 15:3...
# transactions                                                             7
# mean_transaction_amount                                            469.627
# transacton_std_dev                                                 68.0241
# total_ISPs                                                               1
# mean_trans_times                                                   33.9927
# trans_times_std                                                    32.8779
# transaction_frequency                                            0.0294181
# distance_from_border                                                  0.52
# unique_receivers                                                         3
# night_time                                                               0
# major_city                                                             0.8
#
#                         01fad62c3e5b6cbf95a26d59abd3249796e56a1caa027b013b470e06ffc4afba  \
# amounts                  [350.0, 350.0, 350.0, 680.0, 350.0, 350.0, 350...
# locations                [(45.33, -75.67), (45.42, -75.7), (45.33, -75....
# receivers                {'bf6f30e2e6e31010cfcd15eb765b7a4cfc21ff33fe29...
# senderISP                            [Shared Services Canada, Bell Canada]
# time_stamps              [2018-06-01 14:00:51.380-0400, 2018-06-15 15:4...
# transactions                                                            10
# mean_transaction_amount                                                383
# transacton_std_dev                                                 31.3065
# total_ISPs                                                               2
# mean_trans_times                                                   14.7739
# trans_times_std                                                    9.31642
# transaction_frequency                                            0.0676871
# distance_from_border                                               0.74934
# unique_receivers                                                         1
# night_time                                                               0
# major_city                                                            0.09
#
#                         8b11e3e97273699aeca08dbb84f884921c53f7af83144143166db368cb1b7df7  \
# amounts                  [2776.57, 2742.65, 30.0, 776.57, 776.57, 600.0...
# locations                             [(49.28, -123.11), (49.26, -123.16)]
# receivers                {'99802f30b2029bcc495725c61b51464a4bd5a85ccbf3...
# senderISP                              [Bell Canada, Telus Communications]
# time_stamps              [2018-06-01 15:52:35.582-0400, 2018-05-01 13:4...
# transactions                                                            38
# mean_transaction_amount                                            746.537
# transacton_std_dev                                                 119.006
# total_ISPs                                                               2
# mean_trans_times                                                   7.75278
# trans_times_std                                                    6.46932
# transaction_frequency                                             0.128986
# distance_from_border                                                  0.28
# unique_receivers                                                        10
# night_time                                                               3
# major_city                                                               0
#
#                         831b7e058c9542cea19d2fecbebf0e838ee5a0ccaabe06e9b13eab2940cd9c0f  \
# amounts                    [200.0, 100.0, 150.0, 180.0, 60.0, 240.0, 40.0]
# locations                                                [(49.92, -96.96)]
# receivers                {'f2717c125ac73191416ed910bee13fbaaeb1c90d8a7b...
# senderISP                                            [Shaw Communications]
# time_stamps              [2018-06-01 08:22:02.319-0400, 2018-06-01 15:1...
# transactions                                                             7
# mean_transaction_amount                                            138.571
# transacton_std_dev                                                 26.0634
# total_ISPs                                                               1
# mean_trans_times                                                   25.1082
# trans_times_std                                                    20.7802
# transaction_frequency                                            0.0398276
# distance_from_border                                                  0.92
# unique_receivers                                                         3
# night_time                                                               1
# major_city                                                            0.03
#
#                          ...  \
# amounts                  ...
# locations                ...
# receivers                ...
# senderISP                ...
# time_stamps              ...
# transactions             ...
# mean_transaction_amount  ...
# transacton_std_dev       ...
# total_ISPs               ...
# mean_trans_times         ...
# trans_times_std          ...
# transaction_frequency    ...
# distance_from_border     ...
# unique_receivers         ...
# night_time               ...
# major_city               ...
#
#                         1353274bc61ab4fec631779f9ea5c0f9a312527034b859df6a7b97504560810c  \
# amounts                                                             [50.0]
# locations                                               [(49.23, -123.09)]
# receivers                {'eccb1f777dc4f296fd2608c4cb7f5506fc043cf5a3ca...
# senderISP                                           [Telus Communications]
# time_stamps                                 [2017-08-31 23:59:20.877-0400]
# transactions                                                             1
# mean_transaction_amount                                                 50
# transacton_std_dev                                                       0
# total_ISPs                                                               1
# mean_trans_times                                                         0
# trans_times_std                                                          0
# transaction_frequency                                                    0
# distance_from_border                                                  0.23
# unique_receivers                                                         1
# night_time                                                               1
# major_city                                                            0.05
#
#                         d8f6868e404062650b1fc105865c32741804224de10db31f90151d25da7bbf3f  \
# amounts                                                             [40.0]
# locations                                                 [(45.4, -75.73)]
# receivers                {'b4859deb2e5a15e33b480b321bba00f713d44fe160dd...
# senderISP                                                   [Rogers Cable]
# time_stamps                                 [2017-08-31 23:55:26.990-0400]
# transactions                                                             1
# mean_transaction_amount                                                 40
# transacton_std_dev                                                       0
# total_ISPs                                                               1
# mean_trans_times                                                         0
# trans_times_std                                                          0
# transaction_frequency                                                    0
# distance_from_border                                               0.84346
# unique_receivers                                                         1
# night_time                                                               1
# major_city                                                            0.02
#
#                         05bc9b38338301d280a26c5841d9fcd4f90aa89601116412ff455e8ab4477062  \
# amounts                                                            [200.0]
# locations                                                [(42.98, -79.25)]
# receivers                {'fa52e4777438010e3f0dcb10618f047e28f33845865b...
# senderISP                                                   [Cogeco Cable]
# time_stamps                                 [2017-08-31 23:57:03.494-0400]
# transactions                                                             1
# mean_transaction_amount                                                200
# transacton_std_dev                                                       0
# total_ISPs                                                               1
# mean_trans_times                                                         0
# trans_times_std                                                          0
# transaction_frequency                                                    0
# distance_from_border                                                0.1615
# unique_receivers                                                         1
# night_time                                                               1
# major_city                                                            0.67
#
#                         783da53293ca7d1246763514b4c559af348ad7dfb94b959b0a704c46f5f52c34  \
# amounts                                                            [800.0]
# locations                                                [(43.69, -79.76)]
# receivers                {'0a6b2cc63aa34eaabc0acfd054918c6973bd113582e5...
# senderISP                                                   [Rogers Cable]
# time_stamps                                 [2017-08-31 23:04:40.558-0400]
# transactions                                                             1
# mean_transaction_amount                                                800
# transacton_std_dev                                                       0
# total_ISPs                                                               1
# mean_trans_times                                                         0
# trans_times_std                                                          0
# transaction_frequency                                                    0
# distance_from_border                                               0.75352
# unique_receivers                                                         1
# night_time                                                               1
# major_city                                                            0.04
#
#                         c33f4c9784670bbb33b7a1eb621ce317cc79febdae0bc25c4112d332c3c5b732  \
# amounts                                                            [100.0]
# locations                                                 [(43.64, -79.4)]
# receivers                {'7a55e552f338e4532f3609ce5dbbf4fd9891f5c8c319...
# senderISP                                                    [Bell Canada]
# time_stamps                                 [2017-08-31 23:26:07.982-0400]
# transactions                                                             1
# mean_transaction_amount                                                100
# transacton_std_dev                                                       0
# total_ISPs                                                               1
# mean_trans_times                                                         0
# trans_times_std                                                          0
# transaction_frequency                                                    0
# distance_from_border                                                0.5588
# unique_receivers                                                         1
# night_time                                                               1
# major_city                                                            0.01
#
#                         4a0b27c8d31bb704126488a37bbd586eeebe38247bed9d43b79fbdd362d04ffb  \
# amounts                                                           [1000.0]
# locations                                               [(49.12, -123.12)]
# receivers                {'30d4adfb33cb3c4564fdcee6608559e36df85b6927f3...
# senderISP                                            [Shaw Communications]
# time_stamps                                 [2017-08-31 23:57:10.302-0400]
# transactions                                                             1
# mean_transaction_amount                                               1000
# transacton_std_dev                                                       0
# total_ISPs                                                               1
# mean_trans_times                                                         0
# trans_times_std                                                          0
# transaction_frequency                                                    0
# distance_from_border                                                  0.12
# unique_receivers                                                         1
# night_time                                                               1
# major_city                                                            0.16
#
#                         c6495247effccf9064872c4846785e3972a7ba70631f41e6b4187b43c9e9d132  \
# amounts                                                            [440.0]
# locations                                               [(50.02, -119.41)]
# receivers                {'b06a1b5f7824a09ef9a5b482bf459043e374e80f48ce...
# senderISP                                            [Shaw Communications]
# time_stamps                                 [2017-08-31 23:50:26.566-0400]
# transactions                                                             1
# mean_transaction_amount                                                440
# transacton_std_dev                                                       0
# total_ISPs                                                               1
# mean_trans_times                                                         0
# trans_times_std                                                          0
# transaction_frequency                                                    0
# distance_from_border                                                  1.02
# unique_receivers                                                         1
# night_time                                                               1
# major_city                                                            0.13
#
#                         43909c74bc561391b41c955ebcf9e091ce64ba2b2473ee03c3ed30803859f298  \
# amounts                                                            [700.0]
# locations                                               [(49.32, -124.32)]
# receivers                {'858a04e39f9bd4d4e908d87758a86fd850908c07a10f...
# senderISP                                            [Shaw Communications]
# time_stamps                                 [2017-08-31 22:59:58.156-0400]
# transactions                                                             1
# mean_transaction_amount                                                700
# transacton_std_dev                                                       0
# total_ISPs                                                               1
# mean_trans_times                                                         0
# trans_times_std                                                          0
# transaction_frequency                                                    0
# distance_from_border                                                  0.32
# unique_receivers                                                         1
# night_time                                                               0
# major_city                                                            0.04
#
#                         dc3dfde35fabbb4cae101eb8e6289e058dec34006e336832bbb172bea12fef11  \
# amounts                                                            [480.0]
# locations                                                 [(45.5, -73.59)]
# receivers                {'cfa22cf3d791365d43e754bd4fa79dfdc11cf3c04872...
# senderISP                                                    [Bell Canada]
# time_stamps                                 [2017-08-31 23:03:41.750-0400]
# transactions                                                             1
# mean_transaction_amount                                                480
# transacton_std_dev                                                       0
# total_ISPs                                                               1
# mean_trans_times                                                         0
# trans_times_std                                                          0
# transaction_frequency                                                    0
# distance_from_border                                               0.08318
# unique_receivers                                                         1
# night_time                                                               1
# major_city                                                               0
#
#                         02e5ce0630bf03b7a491c7cde335e08dd14358a72da6736b91cec0ca03f939b7
# amounts                                                            [500.0]
# locations                                               [(52.16, -106.69)]
# receivers                {'d5978bf81a7e999dc4ec2acf5eae095c03bf0ef1390f...
# senderISP                                            [Shaw Communications]
# time_stamps                                 [2017-08-31 23:04:53.080-0400]
# transactions                                                             1
# mean_transaction_amount                                                500
# transacton_std_dev                                                       0
# total_ISPs                                                               1
# mean_trans_times                                                         0
# trans_times_std                                                          0
# transaction_frequency                                                    0
# distance_from_border                                                  3.16
# unique_receivers                                                         1
# night_time                                                               1
# major_city                                                            0.03
#
# [16 rows x 1173094 columns]

# %% [markdown]
# # Final Figures for Presentation - Sender

# %%
cluster_amount = 15
w = [0.1, 0.15, 0.08, 0.15, 0.1, 0.06, 0.01, 0.15, 0.2, 0.05]

# %% [markdown]
# # 10D Clustering with Weights

# %%
stop = len(sender.iloc[0])
subset = sender[:stop]
all_data = [subset.loc['transactions'], subset.loc['mean_transaction_amount'], subset.loc['transacton_std_dev'],
            subset.loc['total_ISPs'], subset.loc['mean_trans_times'], subset.loc['trans_times_std'],
            subset.loc['distance_from_border'],subset.loc['unique_receivers'], subset.loc['night_time'], 
            subset.loc['major_city']]

# Normalize Data
for i in range(len(all_data)): 
    all_data[i] = sklearn.preprocessing.scale(all_data[i])

# Add Weights
final = [] 
for i in range(stop):
    temp = []
    for j in range(len(all_data)): 
        temp.append(all_data[j][i] * w[j])
    final.append(temp)

print(len(final))

kmeans = KMeans(n_clusters=cluster_amount, random_state=0).fit(final)
centers = kmeans.cluster_centers_
labels = kmeans.labels_
# Out:
# 1173094

# %%
clusters = {i: np.where(labels == i)[0] for i in range(kmeans.n_clusters)}
for key in clusters.keys(): 
    print(len(clusters[key]))
# Out:
# 97476
# 63830
# 32468
# 415820
# 10789
# 4909
# 845
# 15
# 4629
# 29471
# 74475
# 205989
# 50923
# 54898
# 126557

# %%
# feature indices
i = 3
j = 8

center_x = []
center_y = []

for point in centers:
    center_x.append(point[i])
    center_y.append(point[j])

count = 0 
x = []
y = []

for point in final: 
    x.append(point[i])
    y.append(point[j])
    
fig = plt.figure(figsize=(8,6),dpi=80, facecolor='w', edgecolor='k')
   
plt.scatter(x, y, s=10)

plt.title("N=1000000 Clustering on 10-D Data - Number if ISPs vs. Number of transactions sent from 10pm - 6am")
plt.xlabel('Number of ISPs')
plt.ylabel('Number of Transactions sent from 10pm - 6am')
plt.scatter(center_x,center_y, marker="x",s=100, color="red", alpha=0.8)
plt.show()

# %%
for i in range(len(centers)): 
    if centers[i][3] > .5:
        print(i)
# Out:
# 2

# %%
# feature indices
i = 2
j = 5

center_x = []
center_y = []

for point in centers:
    center_x.append(point[i])
    center_y.append(point[j])

count = 0 
x = []
y = []

for point in final: 
    if count > 100000:
        break
    x.append(point[i])
    y.append(point[j])
    count += 1
    
fig = plt.figure(figsize=(8,6),dpi=80, facecolor='w', edgecolor='k')
   
plt.scatter(x, y, s=10)

plt.title("N=1000000 Clustering on 10-D Data - Standard Deviation on Transaction Amount vs. Standard Deviation on Time Between Transactions")
plt.xlabel('Transaction Amount Standard Deviation')
plt.ylabel('Time Sent Standard Deviation')
plt.scatter(center_x,center_y, marker="x",s=100, color="red", alpha=0.8)
plt.show()

# %%
# feature indices
i = 9
j = 7

center_x = []
center_y = []

for point in centers:
    center_x.append(point[i])
    center_y.append(point[j])

count = 0 
x = []
y = []

for point in final: 
    if count > 500000:
        break
    x.append(point[i])
    y.append(point[j])
    count += 1
    
fig = plt.figure(figsize=(8,6),dpi=80, facecolor='w', edgecolor='k')
   
plt.scatter(x, y, s=10)

plt.title("N=1000000 Clustering on 10-D Data - Distance from Major City vs. Number of Unique Receivers")
plt.xlabel('Distance from Major City')
plt.ylabel('Number of Unique Receivers')
plt.scatter(center_x,center_y, marker="x",s=100, color="red", alpha=0.8)
plt.show()

# %%
# feature indices
i = 2
j = 0

center_x = []
center_y = []

for point in centers:
    center_x.append(point[i])
    center_y.append(point[j])

count = 0 
x = []
y = []

for point in final: 
    if count > 100000:
        break
    x.append(point[i])
    y.append(point[j])
    count += 1 
    
fig = plt.figure(figsize=(8,6),dpi=80, facecolor='w', edgecolor='k')
   
plt.scatter(x, y, s=10)

plt.title("N=1000000 Clustering on 10-D Data - Standard Deviation on Transaction Amount vs. Total Number of Transactions Sent")
plt.xlabel('Standard Deviation on Transaction Amount')
plt.ylabel('Total Number of Transactions Sent')
plt.scatter(center_x,center_y, marker="x",s=100, color="red", alpha=0.8)
plt.show()

# %%
for i in range(len(centers)): 
    if centers[i][0] > 2.5:
        print(i)
# Out:
# 7

# %%
# feature indices
i = 5
j = 1

center_x = []
center_y = []

for point in centers:
    shift = 0.01
    if point[i] + shift > 0:
        center_x.append(point[i] + shift)
        center_y.append(point[j] + point[i])

count = 0 
x = []
y = []

for point in final: 
    if count > 10000:
        break
    if point[i] > 0:
        x.append(point[i])
        y.append(point[j])
        count += 1 
    
fig = plt.figure(figsize=(8,6),dpi=80, facecolor='w', edgecolor='k')
   
plt.scatter(x, y, s=10)

plt.title("N=1000000 Clustering on 10-D Data - Standard Deviation on Time Between Transactions vs. Mean Transaction Amount")
plt.xlabel('Standard Deviation on Time Between Transactions')
plt.ylabel('Mean Transaction Amount')
plt.scatter(center_x,center_y, marker="x",s=100, color="red", alpha=0.8)
plt.show()

# %% [markdown]
# # Final Figures for Presentation - Receiver

# %%
cluster_amount = 15
w = [0.15, 0.15, 0.2, 0.15, 0.2, 0.05, 0.01]

# %%
stop = len(receiver.iloc[0])
subset = receiver[:stop]
all_data = [subset.loc['transactions'], subset.loc['mean_transaction_amount'], subset.loc['transacton_std_dev'], 
            subset.loc['unique_senders'], subset.loc['night_time'], subset.loc['mean_trans_times'], 
            subset.loc['trans_times_std']]

# Normalize Data
for i in range(len(all_data)): 
    all_data[i] = sklearn.preprocessing.scale(all_data[i])

# Add Weights
final = [] 
for i in range(stop):
    temp = []
    for j in range(len(all_data)): 
        temp.append(all_data[j][i] * w[j])
    final.append(temp)

print(len(final))

kmeans = KMeans(n_clusters=cluster_amount, random_state=0).fit(final)
centers = kmeans.cluster_centers_
labels = kmeans.labels_
# Out:
# 2727049

# %%
clusters = {i: np.where(labels == i)[0] for i in range(kmeans.n_clusters)}
for key in clusters.keys(): 
    print(len(clusters[key]))
# Out:
# 1449264
# 50531
# 1
# 46827
# 57
# 167657
# 5301
# 4453
# 3
# 56439
# 165884
# 422
# 456395
# 317226
# 6589

# %%
# feature indices
i = 2
j = 0

center_x = []
center_y = []

for point in centers:
    center_x.append(point[i])
    center_y.append(point[j])

count = 0 
x = []
y = []

for point in final: 
    if count > 2000000:
        break
    if point[j] > 0:
        x.append(point[i])
        y.append(point[j])
        count += 1 
    
fig = plt.figure(figsize=(8,6),dpi=80, facecolor='w', edgecolor='k')
   
plt.scatter(x, y, s=10)

plt.title("N=2000000 Clustering on 10-D Data - Standard Deviation on Transaction Amount vs. Total Number of Transactions Received")
plt.xlabel('Standard Deviation on Transaction Amount')
plt.ylabel('Total Number of Transactions Sent')
plt.scatter(center_x,center_y, marker="x",s=100, color="red", alpha=0.8)
plt.show()

# %%
# feature indices
i = 2
j = 6

center_x = []
center_y = []

for point in centers:
    shift = 0.005
    center_x.append(point[i])
    center_y.append(point[j]+shift)

count = 0 
x = []
y = []

for point in final: 
    if count > 100000:
        break
    if point[j] > 0:
        x.append(point[i])
        y.append(point[j])
        count += 1

fig = plt.figure(figsize=(8,6),dpi=80, facecolor='w', edgecolor='k')
   
plt.scatter(x, y, s=10)

plt.title("N=2000000 Clustering on 10-D Data - Standard Deviation on Transaction Amount vs. Standard Deviation on Time Between Transactions")
plt.xlabel('Transaction Amount Standard Deviation')
plt.ylabel('Time Recieved Standard Deviation')
plt.scatter(center_x,center_y, marker="x",s=100, color="red", alpha=0.8)
plt.show()

# %%
# feature indices
i = 3
j = 4

center_x = []
center_y = []

for point in centers:
    center_x.append(point[i])
    center_y.append(point[j])

count = 0 
x = []
y = []

for point in final: 
    x.append(point[i])
    y.append(point[j])
    
fig = plt.figure(figsize=(8,6),dpi=80, facecolor='w', edgecolor='k')
   
plt.scatter(x, y, s=10)

plt.title("N=2000000 Clustering on 10-D Data - Number of Unique Senders vs. Number of transactions sent from 10pm - 6am")
plt.xlabel('Number of Unique Senders')
plt.ylabel('Number of Transactions sent from 10pm - 6am')
plt.scatter(center_x,center_y, marker="x",s=100, color="red", alpha=0.8)
plt.show()

# %%
for i in range(len(centers)): 
    if centers[i][4] > 60:
        print(i)
# Out:
# 2
# 8
